# %%
import os
from aizynthfinder.interfaces import AiZynthApp
# Out:
# 2024-10-12 00:05:59.654864: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-10-12 00:05:59.665229: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-10-12 00:05:59.668473: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-10-12 00:05:59.677424: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-10-12 00:06:00.332796: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
print("Current Working Directory:", os.getcwd())
app = AiZynthApp("config.yml")
# Out:
# Current Working Directory: /home/chris-vdb/Computational-Chemistry/aizynthfinder-project/expansion-policies/seq2seq-expansion-policy
# Loading template-based expansion policy model from /home/chris-vdb/Computational-Chemistry/aizynthfinder-project/seq2seq-expansion-strategy/data/public-model-data/uspto_model.onnx to uspto
# ---------------------------------------------------------------------------
# NoSuchFile                                Traceback (most recent call last)
# Cell In[2], line 2
#       1 print("Current Working Directory:", os.getcwd())
# ----> 2 app = AiZynthApp("config.yml")
#
# File ~/anaconda3/envs/aizynth-env/lib/python3.10/site-packages/aizynthfinder/interfaces/aizynthapp.py:58, in AiZynthApp.__init__(self, configfile, setup)
#      56 def __init__(self, configfile: str, setup: bool = True) -> None:
#      57     setup_logger(logging.INFO)
# ---> 58     self.finder = AiZynthFinder(configfile=configfile)
#      59     self._input: StrDict = dict()
#      60     self._output: StrDict = dict()
#
# File ~/anaconda3/envs/aizynth-env/lib/python3.10/site-packages/aizynthfinder/aizynthfinder.py:71, in AiZynthFinder.__init__(self, configfile, configdict)
#      68 self._logger = logger()
#      70 if configfile:
# ---> 71     self.config = Configuration.from_file(configfile)
#      72 elif configdict:
#      73     self.config = Configuration.from_dict(configdict)
#
# File ~/anaconda3/envs/aizynth-env/lib/python3.10/site-packages/aizynthfinder/context/config.py:141, in Configuration.from_file(cls, filename)
#     139     txt = txt.replace(item, os.environ[item[2:-1]])
#     140 _config = yaml.load(txt, Loader=yaml.SafeLoader)
# --> 141 return Configuration.from_dict(_config)
#
# File ~/anaconda3/envs/aizynth-env/lib/python3.10/site-packages/aizynthfinder/context/config.py:110, in Configuration.from_dict(cls, source)
#     107 config_obj = Configuration()
#     108 config_obj._update_from_config(dict(source))
# --> 110 config_obj.expansion_policy.load_from_config(**expansion_config)
#     111 config_obj.filter_policy.load_from_config(**filter_config)
#     112 config_obj.stock.load_from_config(**stock_config)
#
# File ~/anaconda3/envs/aizynth-env/lib/python3.10/site-packages/aizynthfinder/context/policy/policies.py:132, in ExpansionPolicy.load_from_config(self, **config)
#     130 if "type" in kwargs:
#     131     del kwargs["type"]
# --> 132 obj = cls(key, self._config, **kwargs)
#     133 self.load(obj)
#
# File ~/anaconda3/envs/aizynth-env/lib/python3.10/site-packages/aizynthfinder/context/policy/expansion_strategies.py:293, in TemplateBasedExpansionStrategy.__init__(self, key, config, **kwargs)
#     288 self.chiral_fingerprints = bool(kwargs.get("chiral_fingerprints", False))
#     290 self._logger.info(
#     291     f"Loading template-based expansion policy model from {source} to {self.key}"
#     292 )
# --> 293 self.model = load_model(source, self.key, self.use_remote_models)
#     295 self._logger.info(f"Loading templates from {templatefile} to {self.key}")
#     296 if templatefile.endswith(".csv.gz") or templatefile.endswith(".csv"):
#
# File ~/anaconda3/envs/aizynth-env/lib/python3.10/site-packages/aizynthfinder/utils/models.py:74, in load_model(source, key, use_remote_models)
#      59 """
#      60 Load model from a configuration specification.
#      61
#    (...)
#      71 :return: a model object with a predict object
#      72 """
#      73 if source.split(".")[-1] == "onnx":
# ---> 74     return LocalOnnxModel(source)
#      76 if not SUPPORT_EXTERNAL_APIS:
#      77     raise ValueError(
#      78         "Tensorflow is not installed - this installation only supports ONNX models"
#      79     )
#
# File ~/anaconda3/envs/aizynth-env/lib/python3.10/site-packages/aizynthfinder/utils/models.py:153, in LocalOnnxModel.__init__(self, filename)
#     150 session_options = onnxruntime.SessionOptions()
#     151 session_options.intra_op_num_threads = _get_thread_count_per_core()
# --> 153 self.model = onnxruntime.InferenceSession(
#     154     filename, sess_options=session_options
#     155 )
#     156 self._model_inputs = self.model.get_inputs()
#     157 self._model_output = self.model.get_outputs()[0]
#
# File ~/anaconda3/envs/aizynth-env/lib/python3.10/site-packages/onnxruntime/capi/onnxruntime_inference_collection.py:419, in InferenceSession.__init__(self, path_or_bytes, sess_options, providers, provider_options, **kwargs)
#     416 disabled_optimizers = kwargs.get("disabled_optimizers")
#     418 try:
# --> 419     self._create_inference_session(providers, provider_options, disabled_optimizers)
#     420 except (ValueError, RuntimeError) as e:
#     421     if self._enable_fallback:
#
# File ~/anaconda3/envs/aizynth-env/lib/python3.10/site-packages/onnxruntime/capi/onnxruntime_inference_collection.py:480, in InferenceSession._create_inference_session(self, providers, provider_options, disabled_optimizers)
#     477 self._register_ep_custom_ops(session_options, providers, provider_options, available_providers)
#     479 if self._model_path:
# --> 480     sess = C.InferenceSession(session_options, self._model_path, True, self._read_config_from_model)
#     481 else:
#     482     sess = C.InferenceSession(session_options, self._model_bytes, False, self._read_config_from_model)
#
# NoSuchFile: [ONNXRuntimeError] : 3 : NO_SUCHFILE : Load model from /home/chris-vdb/Computational-Chemistry/aizynthfinder-project/seq2seq-expansion-strategy/data/public-model-data/uspto_model.onnx failed:Load model /home/chris-vdb/Computational-Chemistry/aizynthfinder-project/seq2seq-expansion-strategy/data/public-model-data/uspto_model.onnx failed. File doesn't exist
